# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
fggraph = build_focused_gflow_graph(g, focus_gflow(g, gflow(g)))
zx.draw(fggraph, labels=True, scale=40)
# Out:
# <div style="overflow:auto" id="graph-output-pRkZWHxX"></div>
# <script type="text/javascript">
# require.config({baseUrl: "../../pyzx/js",paths: {d3: "d3.v5.min"} });
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# require.undef('zx_viewer');
#
# define('zx_viewer', ['d3'], function(d3) {
#
# ...

# %%
traverse_fggraph(fggraph, 15,77)
# list(fggraph.neighbors(65))[0]
# Out:
# True

# %%
for e in old_g.edges():
    e1,e2 = e
    res = zx.heuristics.neighbor_unfusion.get_connected_neighbors(old_g,e1,e2)
    if res and traverse_fggraph(fggraph, res[0][0],res[0][1]):
        print(e1,e2,res)
# Out:
# 5 13 [(16, 15)]
# 5 25 [(22, 24)]
# 5 69 [(72, 71)]
# 5 81 [(78, 80)]
# 5 16 [(13, 15), (22, 8)]
# 5 72 [(69, 71), (78, 6)]
# 6 59 [(65, 7), (62, 61)]
# 6 62 [(59, 61)]
# 6 65 [(50, 52), (59, 7)]
# 7 40 [(43, 42), (46, 92), (28, 92)]
# 7 43 [(40, 42)]
# 7 65 [(66, 52), (59, 6)]
# 25 92 [(33, 40)]
# 40 92 [(33, 25), (7, 28), (7, 46)]
# 52 66 [(65, 7)]

# %%
new_g = pickle.loads(b'\x80\x04\x95t\n\x00\x00\x00\x00\x00\x00\x8c\x12pyzx.graph.graph_s\x94\x8c\x06GraphS\x94\x93\x94)\x81\x94}\x94(\x8c\x06scalar\x94\x8c\x11pyzx.graph.scalar\x94\x8c\x06Scalar\x94\x93\x94)\x81\x94}\x94(\x8c\x06power2\x94K\x19\x8c\x05phase\x94\x8c\tfractions\x94\x8c\x08Fraction\x94\x93\x94\x8c\x031/4\x94\x85\x94R\x94\x8c\nphasenodes\x94]\x94\x8c\x0bfloatfactor\x94G?\xf0\x00\x00\x00\x00\x00\x00\x8c\nis_unknown\x94\x89\x8c\x07is_zero\x94\x89ub\x8c\x0ctrack_phases\x94\x89\x8c\x0bphase_index\x94}\x94(K\x00K\x00K\x01K\x01K\x02K\x02K\x03K\x03K\x04K\x04K\x05K\x05K\x06K\x06K\x07K\x07K\x08K\x08K\tK\tK\rK\rK\x0fK\x0fK\x10K\x10K\x16K\x16K\x18K\x18K\x19K\x19K\x1cK\x1cK!K!K(K(K*K*K+K+K.K.K;K;K=K=K>K>KAKAKBKBKEKEKGKGKHKHKNKNKPKPKQKQKTKTKVKVKWKWKXKXKYKYKZKZu\x8c\x0cphase_master\x94N\x8c\nphase_mult\x94}\x94(K\x00K\x01K\x01K\x01K\x02K\x01K\x03K\x01K\x04K\x01K\x05K\x01K\x06K\x01K\x07K\x01K\x08K\x01K\tK\x01K\nK\x01K\x0bK\x01K\x0cK\x01K\rK\x01K\x0eK\x01K\x0fK\x01K\x10K\x01K\x11K\x01K\x12K\x01K\x13K\x01K\x14K\x01K\x15K\x01K\x16K\x01K\x17K\x01K\x18K\x01K\x19K\x01K\x1aK\x01K\x1bK\x01K\x1cK
\x94K\x04\x8c\x07_rindex\x94}\x94(K\x00K\x00K\x01K\x00K\x02K\x00K\x03K\x00K\x04K\x00K\x05K\x01K\x06K\x01K\x07K\x01K\x08K\x01K\tK\x02K\rK\x05K\x0fK\x06K\x10K\x07K\x16K\nK\x18K\x0bK\x19K\x0cK\x1cK\x0eK!K\x11K(K\x15K*K\x16K+K\x17K.K\x18K;K K=K!K>K"KAK#KBK$KEK&KGK\'KHK(KMK+KNK+KPK,KQK-KTK.KVK0KWK0KXK0KYK0KZK0K\\K\x19K]K\x1cK^K\x1cu\x8c\x05_maxr\x94K0\x8c\x06_vdata\x94}\x94\x8c\x07_inputs\x94(K\x00K\x01K\x02K\x03K\x04t\x94\x8c\x08_outputs\x94(KVKWKXKYKZt\x94ub.')
zx.draw(new_g, labels=True, scale=40)
# fggraph = build_focused_gflow_graph(new_g, focus_gflow(new_g, gflow(new_g)))
# zx.draw(fggraph, labels=True, scale=40)
# Out:
# <div style="overflow:auto" id="graph-output-ZiEP4zYK"></div>
# <script type="text/javascript">
# require.config({baseUrl: "../../pyzx/js",paths: {d3: "d3.v5.min"} });
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# require.undef('zx_viewer');
#
# define('zx_viewer', ['d3'], function(d3) {
#
# ...

# %%
old_focused = focus_gflow(old_g, gflow(old_g))

# %%
for i in [52,65,66,7]:
    print(i,old_focused[1][i])
# Out:
# 52 {66, 71, 77, 87, 88, 59, 62}
# 65 {88}
# 66 {69, 72, 78, 81, 87, 90}
# 7 {88, 59, 62}

# %%
def get_broken_matches(gc, gfl):
    broken_matches = set()
    good_match = None
    for match in zx.heuristics.neighbor_unfusion.lcomp_matcher_all(gc, gfl):
        if match[2]: #is neighbor unfusion match
            orig_phase = gc.phase(match[1][0])
            phaseless_s, phase_s = zx.heuristics.neighbor_unfusion.unfuse_to_neighbor(gc, match[1][0], match[2], Fraction(1,2))
            if not zx.gflow.gflow(gc):
    #             print("broken gflow from match ",match[1][0], match[2])
                broken_matches.add(frozenset((match[1][0], match[2])))
            else:
                if not good_match:
                    vn = list(gc.neighbors(match[1][0]))
                    boundary = False
                    for neighbor in vn:
                        if gc.types()[neighbor] != 1: # no boundaries
                            boundary = True
                    if not boundary:
                        good_match = match

            gc.remove_vertex(phaseless_s)
            gc.remove_vertex(phase_s)
            gc.add_edge(gc.edge(match[1][0], match[2]), 2) #revert all
            gc.set_phase(match[1][0], orig_phase)
    return broken_matches, good_match

def get_extracted_cx_cz_h_stat(g):
    ce = zx.extract_circuit(g.copy())
    ge = ce.to_graph()
    zx.simplify.id_simp(ge)
    c = zx.Circuit.from_graph(ge)
    cx = 0 
    cz = 0
    h = 0
    for g in c.gates:
        if g.name == 'CNOT':
            cx += 1
        if g.name == 'CZ':
            cz += 1
        if g.name == 'HAD':
            h += 1
    return (cx, cz, h)

def calculate_h_edges(g):
    count = 0
    for edge in g.edges():
        if g.edge_type(edge) == 2:
            count += 1
    return count

def edge_list_to_set(edgelist):
    res = []
    for edge in edgelist:
        res.append(frozenset(edge))
    return set(res)

# %%
gfl = zx.gflow.gflow(old_g)[1]
broken, good_match = get_broken_matches(old_g, gfl)
print('g ', copy.deepcopy(old_g), 'broken ', broken, 'brokenlen ', len(broken), 'h_edges ', calculate_h_edges(old_g), 'ext_gates ', get_extracted_cx_cz_h_stat(old_g), 'apply_match ', good_match)
# Out:
# id_simp: 35. 5. 1.  3 iterations
# g  Graph(47 vertices, 68 edges) broken  {frozenset({72, 5}), frozenset({16, 5}), frozenset({66, 7}), frozenset({13, 5}), frozenset({65, 6}), frozenset({62, 6}), frozenset({69, 5}), frozenset({65, 7}), frozenset({28, 7}), frozenset({43, 7}), frozenset({59, 6}), frozenset({92, 46}), frozenset({81, 5}), frozenset({84, 77}), frozenset({40, 7}), frozenset({50, 6}), frozenset({65, 52}), frozenset({5, 22}), frozenset({5, 78}), frozenset({25, 5}), frozenset({8, 16}), frozenset({46, 7}), frozenset({8, 9}), frozenset({40, 92}), frozenset({25, 92}), frozenset({66, 52}), frozenset({72, 6})} brokenlen  27 h_edges  59 ext_gates  (1, 24, 29) apply_match  (-2.0, (13, [15, 9, 5]), 15)

# %%
for edge in broken:
    e1, e2 = edge
    if (e1,e2) in fggraph.edges() or (e2,e1) in fggraph.edges() :
        print(e1,e2)
# Out:
# 66 52

# %%
gfl_c = copy.deepcopy(zx.gflow.gflow(old_g))

# %%
gfl_c
# Out:
# ({86: 0,
#   87: 0,
#   88: 0,
#   89: 0,
#   90: 0,
#   5: 1,
#   46: 1,
#   65: 1,
#   77: 1,
#   84: 1,
#   72: 2,
#   81: 2,
#   80: 3,
#   78: 4,
#   93: 5,
#   94: 6,
#   95: 7,
#   96: 8,
#   6: 9,
#   71: 9,
#   69: 10,
#   66: 11,
#   62: 12,
#   61: 13,
#   59: 14,
#   7: 15,
#   52: 15,
#   1: 16,
#   50: 16,
#   43: 17,
#   92: 17,
#   42: 18,
#   40: 19,
#   33: 20,
#   2: 21,
#   25: 21,
#   28: 21,
#   16: 22,
#   24: 22,
#   22: 23,
#   8: 24,
#   15: 24,
#   0: 25,
#   13: 25,
#   9: 26,
#   3: 26,
#   4: 27},
#  {5: {86},
#   46: {89},
#   65: {88},
#   77: {90},
#   84: {87},
#   72: {77},
#   81: {84},
#   80: {81},
#   78: {80},
#   93: {78},
#   94: {93},
#   95: {94},
#   96: {95},
#   6: {96},
#   71: {72, 96},
#   69: {71},
#   66: {69},
#   62: {65, 66},
#   61: {62},
#   59: {61},
#   7: {59},
#   52: {59, 65},
#   1: {6, 52},
#   50: {52},
#   43: {46, 50},
#   92: {50},
#   42: {43},
#   40: {42},
#   33: {40},
#   2: {7, 33, 92},
#   25: {33},
# ...

# %%
zx.heuristics.gflow_calculation.check_gflow_condition3(new_g, gfl_c)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 zx.heuristics.gflow_calculation.check_gflow_condition3(new_g, gfl_c)
#
# File ~/Code/pyzx-heuristics/demos/heuristic_demos/../../pyzx/heuristics/gflow_calculation.py:208, in check_gflow_condition3(g, gflow)
#     206   print("gflow violates condition 2 because vertex: ",v," appears in its own correction set")
#     207   return False
# --> 208 if not v in get_odd_neighbourhood(g,gflow[1][v]):
#     209   print("gflow violates condition 2 because vertex: ",v," does not appear in the odd neighborhood of its correction set")
#     210   return False
#
# File ~/Code/pyzx-heuristics/demos/heuristic_demos/../../pyzx/heuristics/gflow_calculation.py:19, in get_odd_neighbourhood(g, vertex_set)
#      17 all_neighbors = set()
#      18 for vertex in vertex_set:
# ...
