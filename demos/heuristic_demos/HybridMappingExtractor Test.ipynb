# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import sys; sys.path.append('../..')
import random
import pyzx as zx
from pyzx.heuristics.extraction2.standardextract import HybridMappingExtractor
# Out:
# <style>.container { width:100% !important; }</style>

# %%
random.seed(11)
g = zx.generate.cliffordT(qubits=6, depth=80, p_t=0.3, p_cnot=0.5)
c = zx.Circuit.from_graph(g)
c = zx.optimize.basic_optimization(c.split_phase_gates()).split_phase_gates()
print(c.stats())

zx.draw(c.to_graph())
g = c.to_graph()
zx.simplify.full_reduce(g)
zx.draw(g, scale=40, labels=True)
# Out:
# Circuit  on 6 qubits with 64 gates.
#         11 is the T-count
#         53 Cliffords among which
#         26 2-qubit gates (25 CNOT, 1 other) and
#         8 Hadamard gates.
# <div style="overflow:auto" id="graph-output-90hUuyot"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
extractor = HybridMappingExtractor(g, 'rubidium.json')
extractor.init_frontier()
extractor.extract()
# options = list(extractor.collect_extraction_options())
# Out:
# applied option 0
# frontier gadgets {(24, 35)}
# pivot on 24 7
# gadget_option <pyzx.heuristics.extraction2.standardextract.CircuitOption object at 0x7411a1f300b0>
# gadget_option <pyzx.heuristics.extraction2.standardextract.CircuitOption object at 0x7411a1f68290>
# cnot_addition_options [[CNOT(1,4)], [CNOT(3,4)], [CNOT(0,1), CNOT(3,1), CNOT(5,1)], [CNOT(4,1)]]
# <div style="overflow:auto" id="graph-output-J7ceGu7w"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# ...

# %%
for option in options:
    zx.draw(option.g)
    zx.draw(option.logical_circuit)
# Out:
# <div style="overflow:auto" id="graph-output-hoFrhyg4"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
zx.draw(options[0].g,labels=True)
# Out:
# <div style="overflow:auto" id="graph-output-4tFDkQIn"></div>
# <script type="module">
# var d3;
# if (d3 == null) { d3 = await import("https://cdn.skypack.dev/d3@5"); }
# // PyZX - Python library for quantum circuit rewriting
# //        and optimisation using the ZX-calculus
# // Copyright (C) 2018 - Aleks Kissinger and John van de Wetering
#
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
#
# //    http://www.apache.org/licenses/LICENSE-2.0
#
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# // styling functions
# function nodeColor(t) {
# ...

# %%
options[0].frontier
# Out:
# {0: 6, 1: 9, 2: 7, 3: 11, 4: 8, 5: 13}
